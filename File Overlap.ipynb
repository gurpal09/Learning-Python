# %% [markdown]
# Given two .txt files that have lists of numbers in them, find the numbers that are overlapping. One .txt file has a list of all prime numbers under 1000, and the other .txt file has a list of happy numbers up to 1000.
#
# (If you forgot, prime numbers are numbers that can’t be divided by any other number. And yes, happy numbers are a real thing in mathematics - you can look it up on Wikipedia.

# %%
# Reading Prime Numbers data
primenums = set()

with open('primenumbers.txt','r') as open_file:
    line = open_file.readline()
    while line:
        # print(line)
        line = line.replace("\n","")
        primenums.add(line)
        line = open_file.readline()

# %%
# Now reading happynumbers file

happynums = set()

with open('happynumbers.txt','r') as open_file:
    line = open_file.readline()
    while line:
        # print(line)
        line = line.replace("\n","")
        happynums.add(line)
        line = open_file.readline()

# %%
print(happynums)
print(primenums)
# Out:
# {'820', '653', '133', '13', '763', '100', '193', '632', '863', '129', '694', '899', '937', '31', '79', '440', '617', '391', '319', '379', '649', '665', '82', '362', '638', '91', '998', '716', '23', '293', '860', '109', '49', '784', '208', '802', '921', '556', '310', '203', '932', '644', '912', '1000', '888', '409', '623', '239', '748', '397', '923', '392', '907', '566', '673', '368', '230', '32', '262', '683', '656', '19', '793', '881', '931', '536', '655', '622', '219', '338', '469', '1', '190', '487', '313', '446', '709', '291', '904', '608', '464', '635', '989', '973', '700', '329', '280', '833', '874', '496', '226', '761', '680', '490', '565', '70', '236', '356', '940', '192', '331', '637', '806', '913', '383', '910', '86', '326', '44', '970', '167', '946', '404', '386', '836', '671', '103', '94', '302', '7', '176', '365', '68', '301', '736', '563', '376', '790', '367', '901', '130', '139', '97', '964', '320', '28', '847', '818', '739', '188', '478', '263', '10'}
# ...

# %%
# We can compare using the union function for sets

match = primenums.union(happynums)
for n in match:
    print(n)
# Out:
# 820
# 107
# 653
# 59
# 13
# 763
# 193
# 100
# 632
# 223
# 129
# 694
# 991
# 899
# 79
# 61
# 617
# 440
# 719
# 319
# 379
# 649
# 665
# 509
# 82
# 17
# 571
# 503
# 37
# 23
# 229
# 577
# 293
# 89
# 277
# 157
# 49
# 29
# 208
# 802
# 569
# 932
# 912
# 233
# 353
# 888
# 191
# 947
# 461
# 923
# 631
# 392
# 907
# 566
# 368
# 307
# 262
# 683
# 661
# 656
# 19
# 607
# 931
# 883
# 536
# 599
# 655
# 219
# 439
# 457
# 179
# 677
# 190
# 487
# 347
# 313
# 709
# 977
# 464
# 635
# 989
# 973
# 280
# 827
# 874
# 409
# 857
# 929
# 496
# 761
# 226
# 680
# 73
# 490
# 565
# 70
# 197
# 127
# 269
# 971
# 356
# 637
# 383
# 910
# 541
# 491
# 970
# 151
# 547
# 751
# 404
# 919
# 463
# 769
# 94
# 302
# 7
# 176
# 389
# 467
# 68
# 736
# 376
# 790
# 901
# 659
# 251
# 964
# 619
# 733
# 847
# 818
# 739
# 806
# 188
# 263
# 478
# 401
# 227
# 133
# 181
# 859
# 3
# 613
# 163
# 863
# 131
# 101
# 887
# 937
# 31
# 521
# 997
# 391
# 587
# 11
# 349
# 593
# 421
# 941
# 362
# 773
# 43
# 638
# 91
# 998
# 716
# 809
# 860
# 109
# ...
